# %% [markdown]
# <a href="https://colab.research.google.com/github/LeonardoFabian899/CursoBasicodePython/blob/main/Actividad_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install ColabTurtle
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7641 sha256=c41b0ba2d871aad3f8f9cd2514896d58e5203b4f3d0a3311a36275bf5e54878a
#   Stored in directory: /root/.cache/pip/wheels/5b/86/e8/54f5c8c853606e3a3060bb2e60363cbed632374a12e0f33ffc
# Successfully built ColabTurtle
# ...

# %%
from ColabTurtle.Turtle import *

# %%
import ColabTurtle

# %%
grados = 180
lados = 9
longitud = 100

lados_grados = grados / lados

initializeTurtle(initial_speed=10)

pencolor("red")

for i in range(lados):
  pencolor("blue")
  forward(50)
  width(2)
  left(lados_grados)
  for i in range(lados):
    pencolor("green")
    forward(25)
    width(2)
    right(lados_grados)
    for i in range(lados):
      pencolor("purple")
      forward(10)
      width(2)
      left(lados_grados)
    for i in range(lados):
      pencolor("blue")
      forward(10)
      width(2)
      left(lados_grados)
    for i in range(lados):
      pencolor("green")
      forward(10)
      width(2)
      left(lados_grados)
    for i in range(lados):
      pencolor("purple")
      forward(10)
      width(2)
      left(lados_grados)
    for i in range(lados):
      pencolor("blue")
      forward(10)
      width(2)
      left(lados_grados)
    for i in range(lados):
      pencolor("green")
      forward(10)
      width(2)
      left(lados_grados)
    for i in range(lados):
      pencolor("purple")
      forward(10)
      width(2)
      left(lados_grados)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...
